# %%
import pandas as pd
import numpy as np

team_dict = {
    'Arizona Cardinals': 'ARI',
    'Atlanta Falcons': 'ATL',
    'Baltimore Ravens': 'BAL',
    'Buffalo Bills': 'BUF',
    'Carolina Panthers': 'CAR',
    'Cincinnati Bengals': 'CIN',
    'Chicago Bears': 'CHI',
    'Cleveland Browns': 'CLE',
    'Dallas Cowboys': 'DAL',
    'Denver Broncos': 'DEN',
    'Detroit Lions': 'DET',
    'Green Bay Packers': 'GB',
    'Houston Texans': 'HOU',
    'Indianapolis Colts': 'IND',
    'Jacksonville Jaguars': 'JAX',
    'Kansas City Chiefs': 'KC',
    'Las Vegas Raiders': 'OAK',
    'Los Angeles Chargers': 'LAC',
    'Los Angeles Rams': 'LA',
    'Miami Dolphins': 'MIA',
    'Minnesota Vikings': 'MIN',
    'New England Patriots': 'NE',
    'New Orleans Saints': 'NO',
    'New York Giants': 'NYG',
    'New York Jets': 'NYJ',
    'Philadelphia Eagles': 'PHI',
    'Pittsburgh Steelers': 'PIT',
    'San Francisco 49ers': 'SF',
    'Seattle Seahawks': 'SEA',
    'Tampa Bay Buccaneers': 'TB',
    'Tennessee Titans': 'TEN',
    'Washington Commanders': 'WAS'
}

# %%
# data = pd.read_csv('nfl_09-18.csv', usecols=range(0,40))
# data['game_date'] = pd.to_datetime(data['game_date'])
#data['season'] = data['game_date'].apply(lambda x: f"{x.year}-{x.year + 1}" if x.month >= 7 else f"{x.year - 1}-{x.year}")
#data = pd.read_csv('data.csv')
column_numbers = [42, 166, 167, 168, 169, 174, 175, 178, 179, 182, 183, 188, 189, 190, 191, 194, 195, 203, 204, 205, 218, 219, 220, 226, 227, 231, 232, 233, 238, 240, 241, 249]

# Get the column names for the specified column numbers
#data.drop(columns=list(data.columns[column_numbers]), inplace=True)

data.to_csv('data.csv', index=False)

# %%
data.to_csv('data.csv', index=False)

# %%
len(data['posteam'].unique())
# Out:
# 33

# %%
data.to_csv('data.csv', index=False)
#data['game_date'] = pd.to_datetime(data['game_date'])

# %%
[print(col) for col in data.columns]
# Out:
# play_id
# game_id
# home_team
# away_team
# posteam
# posteam_type
# defteam
# side_of_field
# yardline_100
# game_date
# quarter_seconds_remaining
# half_seconds_remaining
# game_seconds_remaining
# game_half
# quarter_end
# drive
# sp
# qtr
# down
# goal_to_go
# time
# yrdln
# ydstogo
# ydsnet
# desc
# play_type
# yards_gained
# shotgun
# no_huddle
# qb_dropback
# qb_kneel
# qb_spike
# qb_scramble
# pass_length
# pass_location
# air_yards
# yards_after_catch
# run_location
# run_gap
# field_goal_result
# kick_distance
# extra_point_result
# two_point_conv_result
# home_timeouts_remaining
# away_timeouts_remaining
# timeout
# timeout_team
# td_team
# posteam_timeouts_remaining
# defteam_timeouts_remaining
# total_home_score
# total_away_score
# posteam_score
# defteam_score
# score_differential
# posteam_score_post
# defteam_score_post
# score_differential_post
# no_score_prob
# opp_fg_prob
# opp_safety_prob
# opp_td_prob
# fg_prob
# safety_prob
# td_prob
# extra_point_prob
# ...

# %%
temp = data.query('game_id == 2009091000')

# %%
for i, row in temp[['play_type', 'posteam_score', 'defteam_score']].iterrows():
    print(row)
# Out:
# play_type        kickoff
# posteam_score        NaN
# defteam_score        NaN
# Name: 0, dtype: object
# play_type        pass
# posteam_score     0.0
# defteam_score     0.0
# Name: 1, dtype: object
# play_type        run
# posteam_score    0.0
# defteam_score    0.0
# Name: 2, dtype: object
# play_type        pass
# posteam_score     0.0
# defteam_score     0.0
# Name: 3, dtype: object
# play_type        punt
# posteam_score     0.0
# defteam_score     0.0
# Name: 4, dtype: object
# play_type        run
# posteam_score    0.0
# defteam_score    0.0
# Name: 5, dtype: object
# play_type        pass
# posteam_score     0.0
# defteam_score     0.0
# Name: 6, dtype: object
# play_type        run
# posteam_score    0.0
# defteam_score    0.0
# Name: 7, dtype: object
# play_type        punt
# posteam_score     0.0
# defteam_score     0.0
# Name: 8, dtype: object
# play_type        pass
# posteam_score     0.0
# defteam_score     0.0
# Name: 9, dtype: object
# play_type        pass
# ...

# %%
team = 'CHI'
year_data = data.query(f"home_team == '{team}' or away_team == '{team}'")
year = year_data['season'].unique()[0]
game_data = year_data.query(f"season == '{year}'")

# %%
data['season'] = data['game_date'].apply(lambda x: f"{x.year}-{x.year + 1}" if x.month >= 7 else f"{x.year - 1}-{x.year}")
# games = game_data.groupby('game_date').apply(lambda x: (x['home_team'].iloc[0], x['away_team'].iloc[0])).sort_index()
# game_list = []

# %%
date = pd.Series(games.index).dt.date[0]

game_data.query(f"game_date == '{date}'")
# Out:
#       play_id     game_id home_team away_team posteam posteam_type defteam  \
# 2220       36  2009091312        GB       CHI      GB         home     CHI
# 2221       58  2009091312        GB       CHI      GB         home     CHI
# 2222       82  2009091312        GB       CHI      GB         home     CHI
# 2223      103  2009091312        GB       CHI      GB         home     CHI
# 2224      128  2009091312        GB       CHI      GB         home     CHI
# ...       ...         ...       ...       ...     ...          ...     ...
# 2384     3790  2009091312        GB       CHI     CHI         away      GB
# 2385     3830  2009091312        GB       CHI     CHI         away      GB
# 2386     3857  2009091312        GB       CHI      GB         home     CHI
# 2387     3878  2009091312        GB       CHI      GB         home     CHI
# 2388     3899  2009091312        GB       CHI     NaN          NaN     NaN
#
# ...
